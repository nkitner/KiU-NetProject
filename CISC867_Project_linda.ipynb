# %%
# need to add dataset to a folder in google drive
# from google.colab import drive
# drive.mount('/content/drive')

# %%
#%tensorflow_version 2.x

# %%
import tensorflow as tf
import os
from PIL import Image
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
import SimpleITK as sitk
import pickle
from tensorflow import saved_model as sm

# %%
def import_data_numpy(path):
    """
    Imports png images and returns as a list of tensors to be used in training
    :param path: path to directory where images are
    :return: list of Tensors
    """
    tensor_list = []
    for file in os.listdir(path):
        if file.endswith(".png") or file.endswith(".tif"):
            # Converts to RGB because the vessel images are black and white
            png_img = Image.open(os.path.join(path, file)).convert('RGB')
            # Encodes images as tensors and adds to the list
            tensor_list.append(np.array(png_img.getdata()).reshape((128,128,3)))
        # Returns list of tensors to be used in model
    tensor_list = np.asarray(tensor_list)
    return tensor_list

# %%
def _encoder_block_unet(input, num_filters):
    """
    Encoder logic for U-Net
    :param input: KerasTensor
    :param num_filters: Int - number of output filters in convolution
    :return: KerasTensor
    """
    x = layers.Conv2D(num_filters, 3, padding="same")(input)
    x = layers.MaxPool2D((2, 2))(x)
    # x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    return x


def _encoder_block_kinet(input, num_filters):
    """
    Encoder logic for Ki-Net
    :param input: KerasTensor
    :param num_filters: Int - number of output filters in convolution
    :return: KerasTensor
    """
    x = layers.Conv2D(num_filters, 3, padding="same")(input)
    x = layers.UpSampling2D(size=(2, 2), interpolation="bilinear")(x)
    # x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    p = layers.MaxPool2D((2, 2))(x)
    return x


def _decoder_block_unet(input, num_filters):
    """
    Decoder logic for U-Net
    :param input: KerasTensor
    :param num_filters: Int - number of output filters in convolution
    :return: KerasTensor
    """
    x = layers.Conv2D(num_filters, 3, padding="same")(input)
    x = layers.UpSampling2D(size=(2, 2), interpolation="bilinear")(x)
    # x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    return x


def _decoder_block_kinet(input, num_filters):
    """
    Decoder logic for Ki-net
    :param input: KerasTensor
    :param num_filters: Int - number of output filters in convolution
    :return: KerasTensor
    """
    x = layers.Conv2D(num_filters, 3, padding="same")(input)
    x = layers.MaxPool2D((2, 2))(x)
    # x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    print(type(x))
    return x


def _crfb(x1, x2, num_filters, scale_factor):
    """
    CRFB is the cross residual fusion block which fuses the outputs at the specified layers
    from one model to the other, and returns the results as input for the next step.
    :param x1: KerasTensor
    :param x2: KerasTensor
    :param num_filters: Int - number of output filters in convolution
    :param scale_factor: Float - scale factor for resizing (upsampling/downsampling) of output
    :return: KerasTensor
    """
    new_w = int(x2.shape[1] * scale_factor)
    new_h = int(x2.shape[2] * scale_factor)
    out = layers.Conv2D(num_filters, 3, padding="same")(x2)
    out = layers.Activation("relu")(out)
    out = tf.image.resize(out, [new_h, new_w])
    output = layers.Concatenate()([x1, out])
    return output

# %%
def kiunet(input_shape):
    """
    Architecture of the KiU-Net model, which combines the Ki-Net and U-Net architecture
    :param input_shape: Tuple of the shape of the input
    :return: keras.Model
    """
    inputs = layers.Input(shape=input_shape)

    # ENCODER BLOCK #

    s1 = _encoder_block_unet(inputs, 32)  # U NET ENCODER
    k1 = _encoder_block_kinet(inputs, 32)  # KINET ENCODER

    u1 = _crfb(s1, k1, 32, 0.25)  # CRFB U1 UNET
    o1 = _crfb(k1, s1, 32, 4)  # CRFB O1 KINET

    s2 = _encoder_block_unet(u1, 64)  # UNET ENCODER
    k2 = _encoder_block_kinet(o1, 64)  # KINET ENCODER

    u2 = _crfb(s2, k2, 64, 0.0625)  # CRFB U2 UNET
    o2 = _crfb(k2, s2, 64, 16)  # CRFB O2 KINET

    s3 = _encoder_block_unet(u2, 128)  # UNET ENCODER
    k3 = _encoder_block_kinet(o2, 128)  # KINET ENCODER

    u3 = _crfb(s3, k3, 128, 0.015625)  # CRFB U3 UNET
    o3 = _crfb(k3, s2, 128, 32)  # CRFB O3 KINET

    # DECODER BLOCK #

    d1_u = _decoder_block_unet(u3, 64)  # UNET DECODER
    d1_k = _decoder_block_kinet(o3, 64)  # KINET DECODER

    d_u1 = _crfb(d1_u, d1_k, 32, 0.0625)  # CRFB D_U1 UNET
    d_o1 = _crfb(d1_k, d1_u, 32, 16)  # CRFB D_O1 KINET

    out = layers.Concatenate()([d_u1, s2])  # CONCATENTATION D_U1 & S2 UNET
    out1 = layers.Concatenate()([d_o1, k2])  # CONCATENTATION D_O1 & K2 KINET

    d2_u = _decoder_block_unet(out, 32)  # UNET DECODER
    d2_k = _decoder_block_kinet(out1, 32)  # KINET DECODER

    d_u2 = _crfb(d2_u, d2_k, 16, 0.25)  # CRFB D_U2 UNET
    d_o2 = _crfb(d2_k, d2_u, 16, 4)  # CRFB D_O2 KINET

    out = layers.Concatenate()([d_u2, s1])  # CONCATENATION D_U2 & S1 UNET
    out1 = layers.Concatenate()([d_o2, k1])  # CONCATENATION D_O2 & K2 KINET

    d3_u = _decoder_block_unet(out, 16)  # UNET DECODER
    d3_k = _decoder_block_kinet(out1, 16)  # KINET DECODER

    out = layers.Concatenate()([d3_u, d3_k])  # FINAL CONCATENATION OUTPUT FROM UNET AND KINET

    out = layers.Conv2D(3, 3, padding="same", activation="relu")(out)  # FINAL CONVOLUTIONAL LAYER
    kiunet_model = keras.Model(inputs, out, name="U-Net")  # MODEL

    return kiunet_model

# %%
def resizeImg(img, out_size):
    if img.endswith(".png"):
        # Get original image dimensions
        original_image = sitk.ReadImage(img, imageIO="PNGImageIO")
    elif img.endswith(".tif"):
        original_image = sitk.ReadImage(img, imageIO="TIFFImageIO")
    orig_size = original_image.GetSize()
    orig_spacing = original_image.GetSpacing()
    origin = original_image.GetOrigin()
    direction = original_image.GetDirection()

    # Calculate output spacing
    out_spacing = [
        int(np.round(orig_spacing[0] * (orig_size[0] / out_size[0]))),
        int(np.round(orig_spacing[1] * (orig_size[1] / out_size[1])))
        # might have to put RGB channel here?
    ]

    # Set output dimensions
    resampler = sitk.ResampleImageFilter()
    resampler.SetOutputOrigin(origin)
    resampler.SetOutputDirection(direction)
    resampler.SetSize(out_size)
    resampler.SetOutputSpacing(out_spacing)

    return resampler.Execute(original_image)


# Pre-process training dataset
image_num = 1

for img in os.listdir("data/training/av"):
    if img.endswith(".png") or img.endswith(".tif"):
        img = "data/training/av/" + img
        # png_img = Image.open(os.path.join("./training/av", img))
        new_img = resizeImg(img, (128, 128))
        path = "data/training/av/processed_labels/{}_label_downsampled.png".format(image_num)
        sitk.WriteImage(new_img, path)
        image_num += 1

image_num = 1

for img in os.listdir("data/training/images"):
    if img.endswith(".png") or img.endswith(".tif"):
        img = "data/training/images/" + img
        new_img = resizeImg(img, (128, 128))
        path = "data/training/images/processed_labels/{}_img_downsampled.tif".format(image_num)
        sitk.WriteImage(new_img, path)
        image_num += 1

# Pre-process test dataset
image_num = 1

for img in os.listdir("data/testing/av"):
    if img.endswith(".png") or img.endswith(".tif"):
        img = "data/testing/av/" + img
        # png_img = Image.open(os.path.join("./training/av", img))
        new_img = resizeImg(img, (128, 128))
        path = "data/testing/av/processed_labels/{}_label_downsampled.png".format(image_num)
        sitk.WriteImage(new_img, path)
        image_num += 1

image_num = 1

for img in os.listdir("data/testing/images"):
    if img.endswith(".png") or img.endswith(".tif"):
        img = "data/testing/images/" + img
        new_img = resizeImg(img, (128, 128))
        path = "data/testing/images/processed_labels/{}_img_downsampled.tif".format(image_num)
        sitk.WriteImage(new_img, path)
        image_num += 1

# %%
x_train = import_data_numpy("data/training/images/processed_labels")
y_train = import_data_numpy("data/training/av/processed_labels")

x_test = import_data_numpy("data/testing/images/processed_labels")
y_test = import_data_numpy("data/testing/av/processed_labels")

# %%
kiunet_model = kiunet((128,128,3))

# Save the model structure
kiunet_model.save('kiUnet_structure')

kiunet_model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),    ## learning_rate is different from 3D
    loss="binary_crossentropy",
    metrics=[keras.metrics.MeanIoU(num_classes=500)])#check metric
# Out:
# 2021-10-16 14:48:27.446962: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-10-16 14:48:27.447975: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-10-16 14:48:27.451350: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# <class 'tensorflow.python.keras.engine.keras_tensor.KerasTensor'>
# <class 'tensorflow.python.keras.engine.keras_tensor.KerasTensor'>
# <class 'tensorflow.python.keras.engine.keras_tensor.KerasTensor'>
# 2021-10-16 14:48:29.343202: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: kiUnet_structure/assets

# %%
kiunet_model.fit(x_train, y_train, batch_size=1, epochs=400, 
                 validation_data=(x_test, y_test), verbose=1, 
                 callbacks=keras.callbacks.TensorBoard(log_dir="./logs"))    ## log metrics in TensorBoard)
# Out:
# 2021-10-16 14:48:32.014964: I tensorflow/core/profiler/lib/profiler_session.cc:136] Profiler session initializing.
# 2021-10-16 14:48:32.015007: I tensorflow/core/profiler/lib/profiler_session.cc:155] Profiler session started.
# 2021-10-16 14:48:32.015059: I tensorflow/core/profiler/lib/profiler_session.cc:172] Profiler session tear down.
# 2021-10-16 14:48:32.067144: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-10-16 14:48:32.067769: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2294635000 Hz
# Epoch 1/400
#  1/20 [>.............................] - ETA: 3:23 - loss: -40.6707 - mean_io_u: 0.0020
# 2021-10-16 14:48:42.972539: I tensorflow/core/profiler/lib/profiler_session.cc:136] Profiler session initializing.
# 2021-10-16 14:48:42.972601: I tensorflow/core/profiler/lib/profiler_session.cc:155] Profiler session started.
#  2/20 [==>...........................] - ETA: 2:09 - loss: -59.4294 - mean_io_u: 0.0016
# 2021-10-16 14:48:49.978420: I tensorflow/core/profiler/lib/profiler_session.cc:71] Profiler session collecting data.
# 2021-10-16 14:48:49.995843: I tensorflow/core/profiler/lib/profiler_session.cc:172] Profiler session tear down.
# 2021-10-16 14:48:50.038481: I tensorflow/core/profiler/rpc/client/save_profile.cc:137] Creating directory: ./logs/train/plugins/profile/2021_10_16_14_48_49
# 2021-10-16 14:48:50.053444: I tensorflow/core/profiler/rpc/client/save_profile.cc:143] Dumped gzipped tool data for trace.json.gz to ./logs/train/plugins/profile/2021_10_16_14_48_49/caclogin03.trace.json.gz
# 2021-10-16 14:48:50.162180: I tensorflow/core/profiler/rpc/client/save_profile.cc:137] Creating directory: ./logs/train/plugins/profile/2021_10_16_14_48_49
# 2021-10-16 14:48:50.167107: I tensorflow/core/profiler/rpc/client/save_profile.cc:143] Dumped gzipped tool data for memory_profile.json.gz to ./logs/train/plugins/profile/2021_10_16_14_48_49/caclogin03.memory_profile.json.gz
# 2021-10-16 14:48:50.170427: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: ./logs/train/plugins/profile/2021_10_16_14_48_49Dumped tool data for xplane.pb to ./logs/train/plugins/profile/2021_10_16_14_48_49/caclogin03.xplane.pb
# Dumped tool data for overview_page.pb to ./logs/train/plugins/profile/2021_10_16_14_48_49/caclogin03.overview_page.pb
# Dumped tool data for input_pipeline.pb to ./logs/train/plugins/profile/2021_10_16_14_48_49/caclogin03.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to ./logs/train/plugins/profile/2021_10_16_14_48_49/caclogin03.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to ./logs/train/plugins/profile/2021_10_16_14_48_49/caclogin03.kernel_stats.pb
# 20/20 [==============================] - 179s 9s/step - loss: -18.0828 - mean_io_u: 0.0014 - val_loss: 111.9623 - val_mean_io_u: 0.1943
# Epoch 2/400
# 20/20 [==============================] - 173s 9s/step - loss: 117.5429 - mean_io_u: 0.4851 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 3/400
# 20/20 [==============================] - 172s 9s/step - loss: 121.2999 - mean_io_u: 0.4846 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 4/400
# 20/20 [==============================] - 173s 9s/step - loss: 118.1511 - mean_io_u: 0.4850 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 5/400
# 20/20 [==============================] - 174s 9s/step - loss: 119.6325 - mean_io_u: 0.4848 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 6/400
# 20/20 [==============================] - 173s 9s/step - loss: 115.5048 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 7/400
# 20/20 [==============================] - 172s 9s/step - loss: 114.5548 - mean_io_u: 0.4854 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 8/400
# 20/20 [==============================] - 174s 9s/step - loss: 116.4433 - mean_io_u: 0.4852 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 9/400
# 20/20 [==============================] - 172s 9s/step - loss: 113.9501 - mean_io_u: 0.4855 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 10/400
# 20/20 [==============================] - 172s 9s/step - loss: 118.3118 - mean_io_u: 0.4850 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 11/400
# 20/20 [==============================] - 173s 9s/step - loss: 111.4520 - mean_io_u: 0.4858 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 12/400
# 20/20 [==============================] - 173s 9s/step - loss: 123.3352 - mean_io_u: 0.4843 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 13/400
# 20/20 [==============================] - 173s 9s/step - loss: 121.5715 - mean_io_u: 0.4845 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 14/400
# 20/20 [==============================] - 174s 9s/step - loss: 121.3589 - mean_io_u: 0.4846 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 15/400
# 20/20 [==============================] - 173s 9s/step - loss: 111.9984 - mean_io_u: 0.4858 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 16/400
# 20/20 [==============================] - 174s 9s/step - loss: 120.6902 - mean_io_u: 0.4847 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 17/400
# 20/20 [==============================] - 171s 9s/step - loss: 120.0761 - mean_io_u: 0.4847 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 18/400
# 20/20 [==============================] - 175s 9s/step - loss: 122.3941 - mean_io_u: 0.4844 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 19/400
# 20/20 [==============================] - 171s 9s/step - loss: 118.6996 - mean_io_u: 0.4849 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 20/400
# 20/20 [==============================] - 173s 9s/step - loss: 117.7596 - mean_io_u: 0.4850 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 21/400
# 20/20 [==============================] - 172s 9s/step - loss: 117.5999 - mean_io_u: 0.4851 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 22/400
# 20/20 [==============================] - 173s 9s/step - loss: 115.0209 - mean_io_u: 0.4854 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 23/400
# 20/20 [==============================] - 171s 9s/step - loss: 120.7794 - mean_io_u: 0.4846 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 24/400
# 20/20 [==============================] - 174s 9s/step - loss: 120.4625 - mean_io_u: 0.4847 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 25/400
# 20/20 [==============================] - 174s 9s/step - loss: 114.6055 - mean_io_u: 0.4854 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 26/400
# 20/20 [==============================] - 172s 9s/step - loss: 109.5848 - mean_io_u: 0.4861 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 27/400
# 20/20 [==============================] - 174s 9s/step - loss: 118.2704 - mean_io_u: 0.4850 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 28/400
# 20/20 [==============================] - 174s 9s/step - loss: 127.7170 - mean_io_u: 0.4838 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 29/400
# 20/20 [==============================] - 173s 9s/step - loss: 118.6844 - mean_io_u: 0.4849 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 30/400
# 20/20 [==============================] - 171s 9s/step - loss: 123.7278 - mean_io_u: 0.4843 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 31/400
# 20/20 [==============================] - 173s 9s/step - loss: 116.9047 - mean_io_u: 0.4851 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 32/400
# 20/20 [==============================] - 173s 9s/step - loss: 117.2660 - mean_io_u: 0.4851 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 33/400
# 20/20 [==============================] - 173s 9s/step - loss: 115.3399 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 34/400
# 20/20 [==============================] - 173s 9s/step - loss: 115.2742 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 35/400
# 20/20 [==============================] - 174s 9s/step - loss: 123.4736 - mean_io_u: 0.4843 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 36/400
# 20/20 [==============================] - 173s 9s/step - loss: 117.4232 - mean_io_u: 0.4851 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 37/400
# 20/20 [==============================] - 171s 9s/step - loss: 121.8570 - mean_io_u: 0.4845 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 38/400
# 20/20 [==============================] - 171s 9s/step - loss: 119.3648 - mean_io_u: 0.4848 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 39/400
# 20/20 [==============================] - 172s 9s/step - loss: 117.2714 - mean_io_u: 0.4851 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 40/400
# 20/20 [==============================] - 173s 9s/step - loss: 115.5147 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 41/400
# 20/20 [==============================] - 175s 9s/step - loss: 115.7051 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 42/400
# 20/20 [==============================] - 174s 9s/step - loss: 115.4937 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 43/400
# 20/20 [==============================] - 173s 9s/step - loss: 116.4573 - mean_io_u: 0.4852 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 44/400
# 20/20 [==============================] - 173s 9s/step - loss: 117.3446 - mean_io_u: 0.4851 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 45/400
# 20/20 [==============================] - 173s 9s/step - loss: 119.4895 - mean_io_u: 0.4848 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 46/400
# 20/20 [==============================] - 173s 9s/step - loss: 119.4146 - mean_io_u: 0.4848 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 47/400
# 20/20 [==============================] - 171s 9s/step - loss: 117.0830 - mean_io_u: 0.4851 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 48/400
# 20/20 [==============================] - 173s 9s/step - loss: 121.1115 - mean_io_u: 0.4846 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 49/400
# 20/20 [==============================] - 172s 9s/step - loss: 114.0304 - mean_io_u: 0.4855 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 50/400
# 20/20 [==============================] - 173s 9s/step - loss: 115.6647 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 51/400
# 20/20 [==============================] - 171s 9s/step - loss: 118.9772 - mean_io_u: 0.4849 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 52/400
# 20/20 [==============================] - 171s 9s/step - loss: 117.4352 - mean_io_u: 0.4851 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 53/400
# 20/20 [==============================] - 172s 9s/step - loss: 123.9586 - mean_io_u: 0.4842 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 54/400
# 20/20 [==============================] - 175s 9s/step - loss: 122.9120 - mean_io_u: 0.4844 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 55/400
# 20/20 [==============================] - 175s 9s/step - loss: 120.8698 - mean_io_u: 0.4846 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 56/400
# 20/20 [==============================] - 174s 9s/step - loss: 122.8745 - mean_io_u: 0.4844 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 57/400
# 20/20 [==============================] - 173s 9s/step - loss: 116.4885 - mean_io_u: 0.4852 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 58/400
# 20/20 [==============================] - 171s 9s/step - loss: 112.1437 - mean_io_u: 0.4857 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 59/400
# 20/20 [==============================] - 173s 9s/step - loss: 110.1017 - mean_io_u: 0.4860 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 60/400
# 20/20 [==============================] - 173s 9s/step - loss: 115.4424 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 61/400
# 20/20 [==============================] - 172s 9s/step - loss: 111.2602 - mean_io_u: 0.4859 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 62/400
# 20/20 [==============================] - 175s 9s/step - loss: 115.6460 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 63/400
# 20/20 [==============================] - 173s 9s/step - loss: 116.4176 - mean_io_u: 0.4852 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 64/400
# 20/20 [==============================] - 170s 9s/step - loss: 114.6242 - mean_io_u: 0.4854 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 65/400
# 20/20 [==============================] - 172s 9s/step - loss: 125.8186 - mean_io_u: 0.4840 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 66/400
# 20/20 [==============================] - 173s 9s/step - loss: 118.1457 - mean_io_u: 0.4850 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 67/400
# 20/20 [==============================] - 172s 9s/step - loss: 119.8490 - mean_io_u: 0.4848 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 68/400
# 20/20 [==============================] - 174s 9s/step - loss: 120.5564 - mean_io_u: 0.4847 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 69/400
# 20/20 [==============================] - 173s 9s/step - loss: 113.0303 - mean_io_u: 0.4856 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 70/400
# 20/20 [==============================] - 172s 9s/step - loss: 114.1923 - mean_io_u: 0.4855 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 71/400
# 20/20 [==============================] - 174s 9s/step - loss: 115.9945 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 72/400
# 20/20 [==============================] - 175s 9s/step - loss: 122.1856 - mean_io_u: 0.4845 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 73/400
# 20/20 [==============================] - 172s 9s/step - loss: 121.8913 - mean_io_u: 0.4845 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 74/400
# 20/20 [==============================] - 173s 9s/step - loss: 121.6809 - mean_io_u: 0.4845 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 75/400
# 20/20 [==============================] - 172s 9s/step - loss: 114.6794 - mean_io_u: 0.4854 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 76/400
# 20/20 [==============================] - 174s 9s/step - loss: 118.0420 - mean_io_u: 0.4850 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 77/400
# 20/20 [==============================] - 173s 9s/step - loss: 116.0131 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 78/400
# 20/20 [==============================] - 175s 9s/step - loss: 122.9080 - mean_io_u: 0.4844 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 79/400
# 20/20 [==============================] - 171s 9s/step - loss: 125.8848 - mean_io_u: 0.4840 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 80/400
# 20/20 [==============================] - 172s 9s/step - loss: 114.7167 - mean_io_u: 0.4854 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 81/400
# 20/20 [==============================] - 174s 9s/step - loss: 117.2067 - mean_io_u: 0.4851 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 82/400
# 20/20 [==============================] - 173s 9s/step - loss: 113.7461 - mean_io_u: 0.4855 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 83/400
# 20/20 [==============================] - 175s 9s/step - loss: 112.8048 - mean_io_u: 0.4857 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 84/400
# 20/20 [==============================] - 172s 9s/step - loss: 123.5922 - mean_io_u: 0.4843 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 85/400
# 20/20 [==============================] - 175s 9s/step - loss: 120.2186 - mean_io_u: 0.4847 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 86/400
# 20/20 [==============================] - 173s 9s/step - loss: 121.9895 - mean_io_u: 0.4845 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 87/400
# 20/20 [==============================] - 173s 9s/step - loss: 110.4696 - mean_io_u: 0.4860 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 88/400
# 20/20 [==============================] - 172s 9s/step - loss: 118.0420 - mean_io_u: 0.4850 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 89/400
# 20/20 [==============================] - 172s 9s/step - loss: 117.2188 - mean_io_u: 0.4851 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 90/400
# 20/20 [==============================] - 174s 9s/step - loss: 112.2426 - mean_io_u: 0.4857 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 91/400
# 20/20 [==============================] - 174s 9s/step - loss: 121.4118 - mean_io_u: 0.4846 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 92/400
# 20/20 [==============================] - 173s 9s/step - loss: 119.1062 - mean_io_u: 0.4849 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 93/400
# 20/20 [==============================] - 175s 9s/step - loss: 115.4881 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 94/400
# 20/20 [==============================] - 172s 9s/step - loss: 113.1733 - mean_io_u: 0.4856 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 95/400
# 20/20 [==============================] - 172s 9s/step - loss: 119.9804 - mean_io_u: 0.4847 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 96/400
# 20/20 [==============================] - 173s 9s/step - loss: 115.2954 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 97/400
# 20/20 [==============================] - 171s 9s/step - loss: 124.9047 - mean_io_u: 0.4841 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 98/400
# 20/20 [==============================] - 174s 9s/step - loss: 119.4102 - mean_io_u: 0.4848 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 99/400
# 20/20 [==============================] - 174s 9s/step - loss: 123.2677 - mean_io_u: 0.4843 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 100/400
# 20/20 [==============================] - 175s 9s/step - loss: 124.2379 - mean_io_u: 0.4842 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 101/400
# 20/20 [==============================] - 172s 9s/step - loss: 113.0811 - mean_io_u: 0.4856 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 102/400
# 20/20 [==============================] - 174s 9s/step - loss: 116.5515 - mean_io_u: 0.4852 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 103/400
# 20/20 [==============================] - 172s 9s/step - loss: 116.5880 - mean_io_u: 0.4852 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 104/400
# 20/20 [==============================] - 171s 9s/step - loss: 111.2311 - mean_io_u: 0.4859 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 105/400
# 20/20 [==============================] - 171s 9s/step - loss: 113.9013 - mean_io_u: 0.4855 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 106/400
# 20/20 [==============================] - 172s 9s/step - loss: 113.2925 - mean_io_u: 0.4856 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 107/400
# 20/20 [==============================] - 173s 9s/step - loss: 117.0690 - mean_io_u: 0.4851 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 108/400
# 20/20 [==============================] - 171s 9s/step - loss: 120.5606 - mean_io_u: 0.4847 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 109/400
# 20/20 [==============================] - 174s 9s/step - loss: 116.5894 - mean_io_u: 0.4852 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 110/400
# 20/20 [==============================] - 174s 9s/step - loss: 117.6238 - mean_io_u: 0.4850 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 111/400
# 20/20 [==============================] - 173s 9s/step - loss: 120.3025 - mean_io_u: 0.4847 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 112/400
# 20/20 [==============================] - 173s 9s/step - loss: 118.1082 - mean_io_u: 0.4850 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 113/400
# 20/20 [==============================] - 175s 9s/step - loss: 118.2469 - mean_io_u: 0.4850 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 114/400
# 20/20 [==============================] - 173s 9s/step - loss: 127.2089 - mean_io_u: 0.4838 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 115/400
# 20/20 [==============================] - 173s 9s/step - loss: 115.8725 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 116/400
# 20/20 [==============================] - 174s 9s/step - loss: 119.1532 - mean_io_u: 0.4849 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 117/400
# 20/20 [==============================] - 175s 9s/step - loss: 113.8286 - mean_io_u: 0.4855 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 118/400
# 20/20 [==============================] - 175s 9s/step - loss: 114.7350 - mean_io_u: 0.4854 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 119/400
# 20/20 [==============================] - 174s 9s/step - loss: 119.3506 - mean_io_u: 0.4848 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 120/400
# 20/20 [==============================] - 175s 9s/step - loss: 113.9238 - mean_io_u: 0.4855 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 121/400
# 20/20 [==============================] - 170s 9s/step - loss: 122.0423 - mean_io_u: 0.4845 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 122/400
# 20/20 [==============================] - 174s 9s/step - loss: 121.3677 - mean_io_u: 0.4846 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 123/400
# 20/20 [==============================] - 173s 9s/step - loss: 118.1867 - mean_io_u: 0.4850 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 124/400
# 20/20 [==============================] - 175s 9s/step - loss: 118.6149 - mean_io_u: 0.4849 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 125/400
# 20/20 [==============================] - 171s 9s/step - loss: 117.5026 - mean_io_u: 0.4851 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 126/400
# 20/20 [==============================] - 172s 9s/step - loss: 114.1470 - mean_io_u: 0.4855 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 127/400
# 20/20 [==============================] - 174s 9s/step - loss: 121.9372 - mean_io_u: 0.4845 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 128/400
# 20/20 [==============================] - 171s 9s/step - loss: 113.1508 - mean_io_u: 0.4856 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 129/400
# 20/20 [==============================] - 173s 9s/step - loss: 120.5788 - mean_io_u: 0.4847 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 130/400
# 20/20 [==============================] - 172s 9s/step - loss: 113.8696 - mean_io_u: 0.4855 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 131/400
# 20/20 [==============================] - 171s 9s/step - loss: 124.2929 - mean_io_u: 0.4842 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 132/400
# 20/20 [==============================] - 173s 9s/step - loss: 116.2845 - mean_io_u: 0.4852 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 133/400
# 20/20 [==============================] - 172s 9s/step - loss: 115.2815 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 134/400
# 20/20 [==============================] - 172s 9s/step - loss: 126.2445 - mean_io_u: 0.4840 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 135/400
# 20/20 [==============================] - 172s 9s/step - loss: 117.9517 - mean_io_u: 0.4850 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 136/400
# 20/20 [==============================] - 173s 9s/step - loss: 115.5200 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 137/400
# 20/20 [==============================] - 172s 9s/step - loss: 116.0866 - mean_io_u: 0.4852 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 138/400
# 20/20 [==============================] - 172s 9s/step - loss: 117.2430 - mean_io_u: 0.4851 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 139/400
# 20/20 [==============================] - 175s 9s/step - loss: 111.3913 - mean_io_u: 0.4858 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 140/400
# 20/20 [==============================] - 178s 9s/step - loss: 111.8068 - mean_io_u: 0.4858 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 141/400
# 20/20 [==============================] - 183s 9s/step - loss: 120.2289 - mean_io_u: 0.4847 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 142/400
# 20/20 [==============================] - 179s 9s/step - loss: 112.9156 - mean_io_u: 0.4856 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 143/400
# 20/20 [==============================] - 171s 9s/step - loss: 116.3342 - mean_io_u: 0.4852 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 144/400
# 20/20 [==============================] - 173s 9s/step - loss: 118.4254 - mean_io_u: 0.4849 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 145/400
# 20/20 [==============================] - 174s 9s/step - loss: 121.5372 - mean_io_u: 0.4846 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 146/400
# 20/20 [==============================] - 174s 9s/step - loss: 118.8929 - mean_io_u: 0.4849 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 147/400
# 20/20 [==============================] - 172s 9s/step - loss: 114.8178 - mean_io_u: 0.4854 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 148/400
# 20/20 [==============================] - 172s 9s/step - loss: 115.9241 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 149/400
# 20/20 [==============================] - 173s 9s/step - loss: 121.9428 - mean_io_u: 0.4845 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 150/400
# 20/20 [==============================] - 173s 9s/step - loss: 123.3742 - mean_io_u: 0.4843 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 151/400
# 20/20 [==============================] - 171s 9s/step - loss: 116.6116 - mean_io_u: 0.4852 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 152/400
# 20/20 [==============================] - 174s 9s/step - loss: 111.5652 - mean_io_u: 0.4858 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 153/400
# 20/20 [==============================] - 172s 9s/step - loss: 112.2947 - mean_io_u: 0.4857 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 154/400
# 20/20 [==============================] - 172s 9s/step - loss: 112.6826 - mean_io_u: 0.4857 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 155/400
# 20/20 [==============================] - 172s 9s/step - loss: 115.5215 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 156/400
# 20/20 [==============================] - 171s 9s/step - loss: 116.4230 - mean_io_u: 0.4852 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 157/400
# 20/20 [==============================] - 174s 9s/step - loss: 115.3763 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 158/400
# 20/20 [==============================] - 173s 9s/step - loss: 113.8467 - mean_io_u: 0.4855 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 159/400
# 20/20 [==============================] - 173s 9s/step - loss: 117.5048 - mean_io_u: 0.4851 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 160/400
# 20/20 [==============================] - 173s 9s/step - loss: 115.8061 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 161/400
# 20/20 [==============================] - 171s 9s/step - loss: 119.4746 - mean_io_u: 0.4848 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 162/400
# 20/20 [==============================] - 174s 9s/step - loss: 119.1271 - mean_io_u: 0.4849 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 163/400
# 20/20 [==============================] - 173s 9s/step - loss: 113.8245 - mean_io_u: 0.4855 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 164/400
# 20/20 [==============================] - 172s 9s/step - loss: 118.8791 - mean_io_u: 0.4849 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 165/400
# 20/20 [==============================] - 174s 9s/step - loss: 115.1295 - mean_io_u: 0.4854 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 166/400
# 20/20 [==============================] - 171s 9s/step - loss: 121.7103 - mean_io_u: 0.4845 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 167/400
# 20/20 [==============================] - 173s 9s/step - loss: 116.8551 - mean_io_u: 0.4851 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 168/400
# 20/20 [==============================] - 174s 9s/step - loss: 114.0083 - mean_io_u: 0.4855 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 169/400
# 20/20 [==============================] - 173s 9s/step - loss: 115.5992 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 170/400
# 20/20 [==============================] - 172s 9s/step - loss: 115.4508 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 171/400
# 20/20 [==============================] - 174s 9s/step - loss: 111.8094 - mean_io_u: 0.4858 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 172/400
# 20/20 [==============================] - 172s 9s/step - loss: 118.9830 - mean_io_u: 0.4849 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 173/400
# 20/20 [==============================] - 173s 9s/step - loss: 112.8449 - mean_io_u: 0.4857 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 174/400
# 20/20 [==============================] - 174s 9s/step - loss: 125.0918 - mean_io_u: 0.4841 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 175/400
# 20/20 [==============================] - 174s 9s/step - loss: 116.0671 - mean_io_u: 0.4852 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 176/400
# 20/20 [==============================] - 173s 9s/step - loss: 113.8452 - mean_io_u: 0.4855 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 177/400
# 20/20 [==============================] - 175s 9s/step - loss: 123.2225 - mean_io_u: 0.4843 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 178/400
# 20/20 [==============================] - 174s 9s/step - loss: 123.8428 - mean_io_u: 0.4843 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 179/400
# 20/20 [==============================] - 173s 9s/step - loss: 125.4785 - mean_io_u: 0.4840 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 180/400
# 20/20 [==============================] - 173s 9s/step - loss: 116.1382 - mean_io_u: 0.4852 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 181/400
# 20/20 [==============================] - 173s 9s/step - loss: 125.9505 - mean_io_u: 0.4840 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 182/400
# 20/20 [==============================] - 172s 9s/step - loss: 120.4503 - mean_io_u: 0.4847 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 183/400
# 20/20 [==============================] - 173s 9s/step - loss: 118.9577 - mean_io_u: 0.4849 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 184/400
# 20/20 [==============================] - 173s 9s/step - loss: 117.2300 - mean_io_u: 0.4851 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 185/400
# 20/20 [==============================] - 173s 9s/step - loss: 117.6680 - mean_io_u: 0.4850 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 186/400
# 20/20 [==============================] - 173s 9s/step - loss: 112.6741 - mean_io_u: 0.4857 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 187/400
# 20/20 [==============================] - 175s 9s/step - loss: 114.2524 - mean_io_u: 0.4855 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 188/400
# 20/20 [==============================] - 173s 9s/step - loss: 124.5272 - mean_io_u: 0.4842 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 189/400
# 20/20 [==============================] - 174s 9s/step - loss: 118.4167 - mean_io_u: 0.4849 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 190/400
# 20/20 [==============================] - 172s 9s/step - loss: 119.0769 - mean_io_u: 0.4849 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 191/400
# 20/20 [==============================] - 173s 9s/step - loss: 115.6566 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 192/400
# 20/20 [==============================] - 173s 9s/step - loss: 125.0346 - mean_io_u: 0.4841 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 193/400
# 20/20 [==============================] - 172s 9s/step - loss: 119.1316 - mean_io_u: 0.4849 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 194/400
# 20/20 [==============================] - 173s 9s/step - loss: 125.7742 - mean_io_u: 0.4840 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 195/400
# 20/20 [==============================] - 173s 9s/step - loss: 114.2333 - mean_io_u: 0.4855 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 196/400
# 20/20 [==============================] - 172s 9s/step - loss: 114.2823 - mean_io_u: 0.4855 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 197/400
# 20/20 [==============================] - 172s 9s/step - loss: 119.9970 - mean_io_u: 0.4847 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 198/400
# 20/20 [==============================] - 173s 9s/step - loss: 117.4161 - mean_io_u: 0.4851 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 199/400
# 20/20 [==============================] - 172s 9s/step - loss: 113.1463 - mean_io_u: 0.4856 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 200/400
# 20/20 [==============================] - 173s 9s/step - loss: 115.7212 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 201/400
# 20/20 [==============================] - 173s 9s/step - loss: 122.1893 - mean_io_u: 0.4845 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 202/400
# 20/20 [==============================] - 173s 9s/step - loss: 112.9761 - mean_io_u: 0.4856 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 203/400
# 20/20 [==============================] - 172s 9s/step - loss: 121.8797 - mean_io_u: 0.4845 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 204/400
# 20/20 [==============================] - 173s 9s/step - loss: 119.4710 - mean_io_u: 0.4848 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 205/400
# 20/20 [==============================] - 175s 9s/step - loss: 111.1175 - mean_io_u: 0.4859 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 206/400
# 20/20 [==============================] - 172s 9s/step - loss: 116.7419 - mean_io_u: 0.4852 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 207/400
# 20/20 [==============================] - 174s 9s/step - loss: 114.6317 - mean_io_u: 0.4854 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 208/400
# 20/20 [==============================] - 173s 9s/step - loss: 126.1238 - mean_io_u: 0.4840 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 209/400
# 20/20 [==============================] - 171s 9s/step - loss: 114.0336 - mean_io_u: 0.4855 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 210/400
# 20/20 [==============================] - 171s 9s/step - loss: 118.1469 - mean_io_u: 0.4850 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 211/400
# 20/20 [==============================] - 171s 9s/step - loss: 113.2066 - mean_io_u: 0.4856 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 212/400
# 20/20 [==============================] - 175s 9s/step - loss: 117.9712 - mean_io_u: 0.4850 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 213/400
# 20/20 [==============================] - 173s 9s/step - loss: 114.6136 - mean_io_u: 0.4854 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 214/400
# 20/20 [==============================] - 172s 9s/step - loss: 119.0309 - mean_io_u: 0.4849 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 215/400
# 20/20 [==============================] - 174s 9s/step - loss: 117.1643 - mean_io_u: 0.4851 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 216/400
# 20/20 [==============================] - 173s 9s/step - loss: 115.5363 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 217/400
# 20/20 [==============================] - 174s 9s/step - loss: 115.4086 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 218/400
# 20/20 [==============================] - 173s 9s/step - loss: 112.5833 - mean_io_u: 0.4857 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 219/400
# 20/20 [==============================] - 172s 9s/step - loss: 114.6018 - mean_io_u: 0.4854 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 220/400
# 20/20 [==============================] - 171s 9s/step - loss: 119.6589 - mean_io_u: 0.4848 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 221/400
# 20/20 [==============================] - 172s 9s/step - loss: 118.7350 - mean_io_u: 0.4849 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 222/400
# 20/20 [==============================] - 176s 9s/step - loss: 120.4920 - mean_io_u: 0.4847 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 223/400
# 20/20 [==============================] - 174s 9s/step - loss: 117.7988 - mean_io_u: 0.4850 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 224/400
# 20/20 [==============================] - 174s 9s/step - loss: 120.2988 - mean_io_u: 0.4847 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 225/400
# 20/20 [==============================] - 173s 9s/step - loss: 117.4004 - mean_io_u: 0.4851 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 226/400
# 20/20 [==============================] - 174s 9s/step - loss: 116.1287 - mean_io_u: 0.4852 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 227/400
# 20/20 [==============================] - 172s 9s/step - loss: 119.6037 - mean_io_u: 0.4848 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 228/400
# 20/20 [==============================] - 173s 9s/step - loss: 120.8782 - mean_io_u: 0.4846 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 229/400
# 20/20 [==============================] - 172s 9s/step - loss: 114.9157 - mean_io_u: 0.4854 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 230/400
# 20/20 [==============================] - 174s 9s/step - loss: 122.6464 - mean_io_u: 0.4844 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 231/400
# 20/20 [==============================] - 172s 9s/step - loss: 114.5244 - mean_io_u: 0.4854 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 232/400
# 20/20 [==============================] - 172s 9s/step - loss: 115.9687 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 233/400
# 20/20 [==============================] - 171s 9s/step - loss: 114.7722 - mean_io_u: 0.4854 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 234/400
# 20/20 [==============================] - 173s 9s/step - loss: 120.7166 - mean_io_u: 0.4847 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 235/400
# 20/20 [==============================] - 172s 9s/step - loss: 119.4880 - mean_io_u: 0.4848 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 236/400
# 20/20 [==============================] - 175s 9s/step - loss: 113.0287 - mean_io_u: 0.4856 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 237/400
# 20/20 [==============================] - 173s 9s/step - loss: 120.4388 - mean_io_u: 0.4847 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 238/400
# 20/20 [==============================] - 172s 9s/step - loss: 112.5015 - mean_io_u: 0.4857 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 239/400
# 20/20 [==============================] - 173s 9s/step - loss: 115.2706 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 240/400
# 20/20 [==============================] - 174s 9s/step - loss: 115.4250 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 241/400
# 20/20 [==============================] - 174s 9s/step - loss: 123.1329 - mean_io_u: 0.4843 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 242/400
# 20/20 [==============================] - 171s 9s/step - loss: 120.2074 - mean_io_u: 0.4847 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 243/400
# 20/20 [==============================] - 173s 9s/step - loss: 117.7434 - mean_io_u: 0.4850 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 244/400
# 20/20 [==============================] - 176s 9s/step - loss: 111.1088 - mean_io_u: 0.4859 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 245/400
# 20/20 [==============================] - 175s 9s/step - loss: 115.6454 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 246/400
# 20/20 [==============================] - 176s 9s/step - loss: 118.9534 - mean_io_u: 0.4849 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 247/400
# 20/20 [==============================] - 173s 9s/step - loss: 125.3515 - mean_io_u: 0.4841 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 248/400
# 20/20 [==============================] - 173s 9s/step - loss: 121.7620 - mean_io_u: 0.4845 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 249/400
# 20/20 [==============================] - 172s 9s/step - loss: 120.5853 - mean_io_u: 0.4847 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 250/400
# 20/20 [==============================] - 173s 9s/step - loss: 116.8785 - mean_io_u: 0.4851 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 251/400
# 20/20 [==============================] - 172s 9s/step - loss: 114.7925 - mean_io_u: 0.4854 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 252/400
# 20/20 [==============================] - 172s 9s/step - loss: 121.2669 - mean_io_u: 0.4846 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 253/400
# 20/20 [==============================] - 171s 9s/step - loss: 120.7811 - mean_io_u: 0.4846 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 254/400
# 20/20 [==============================] - 173s 9s/step - loss: 118.7789 - mean_io_u: 0.4849 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 255/400
# 20/20 [==============================] - 174s 9s/step - loss: 117.4964 - mean_io_u: 0.4851 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 256/400
# 20/20 [==============================] - 172s 9s/step - loss: 123.8583 - mean_io_u: 0.4843 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 257/400
# 20/20 [==============================] - 173s 9s/step - loss: 116.7442 - mean_io_u: 0.4852 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 258/400
# 20/20 [==============================] - 175s 9s/step - loss: 114.1611 - mean_io_u: 0.4855 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 259/400
# 20/20 [==============================] - 174s 9s/step - loss: 121.6502 - mean_io_u: 0.4845 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 260/400
# 20/20 [==============================] - 173s 9s/step - loss: 117.9528 - mean_io_u: 0.4850 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 261/400
# 20/20 [==============================] - 173s 9s/step - loss: 117.3466 - mean_io_u: 0.4851 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 262/400
# 20/20 [==============================] - 175s 9s/step - loss: 120.4471 - mean_io_u: 0.4847 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 263/400
# 20/20 [==============================] - 172s 9s/step - loss: 124.7095 - mean_io_u: 0.4841 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 264/400
# 20/20 [==============================] - 172s 9s/step - loss: 127.0399 - mean_io_u: 0.4839 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 265/400
# 20/20 [==============================] - 174s 9s/step - loss: 114.4965 - mean_io_u: 0.4854 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 266/400
# 20/20 [==============================] - 172s 9s/step - loss: 121.3257 - mean_io_u: 0.4846 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 267/400
# 20/20 [==============================] - 173s 9s/step - loss: 116.9317 - mean_io_u: 0.4851 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 268/400
# 20/20 [==============================] - 171s 9s/step - loss: 118.0678 - mean_io_u: 0.4850 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 269/400
# 20/20 [==============================] - 172s 9s/step - loss: 120.3120 - mean_io_u: 0.4847 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 270/400
# 20/20 [==============================] - 173s 9s/step - loss: 115.6438 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 271/400
# 20/20 [==============================] - 174s 9s/step - loss: 119.9534 - mean_io_u: 0.4848 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 272/400
# 20/20 [==============================] - 174s 9s/step - loss: 118.0503 - mean_io_u: 0.4850 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 273/400
# 20/20 [==============================] - 173s 9s/step - loss: 124.5503 - mean_io_u: 0.4842 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 274/400
# 20/20 [==============================] - 175s 9s/step - loss: 119.9575 - mean_io_u: 0.4848 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 275/400
# 20/20 [==============================] - 169s 9s/step - loss: 119.8305 - mean_io_u: 0.4848 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 276/400
# 20/20 [==============================] - 174s 9s/step - loss: 116.7198 - mean_io_u: 0.4852 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 277/400
# 20/20 [==============================] - 173s 9s/step - loss: 116.1504 - mean_io_u: 0.4852 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 278/400
# 20/20 [==============================] - 174s 9s/step - loss: 115.0485 - mean_io_u: 0.4854 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 279/400
# 20/20 [==============================] - 172s 9s/step - loss: 119.4714 - mean_io_u: 0.4848 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 280/400
# 20/20 [==============================] - 173s 9s/step - loss: 121.0711 - mean_io_u: 0.4846 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 281/400
# 20/20 [==============================] - 172s 9s/step - loss: 118.8020 - mean_io_u: 0.4849 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 282/400
# 20/20 [==============================] - 174s 9s/step - loss: 120.3424 - mean_io_u: 0.4847 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 283/400
# 20/20 [==============================] - 172s 9s/step - loss: 123.1703 - mean_io_u: 0.4843 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 284/400
# 20/20 [==============================] - 172s 9s/step - loss: 117.0804 - mean_io_u: 0.4851 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 285/400
# 20/20 [==============================] - 173s 9s/step - loss: 111.9028 - mean_io_u: 0.4858 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 286/400
# 20/20 [==============================] - 173s 9s/step - loss: 118.2252 - mean_io_u: 0.4850 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 287/400
# 20/20 [==============================] - 173s 9s/step - loss: 122.3438 - mean_io_u: 0.4844 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 288/400
# 20/20 [==============================] - 174s 9s/step - loss: 118.4770 - mean_io_u: 0.4849 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 289/400
# 20/20 [==============================] - 172s 9s/step - loss: 119.4338 - mean_io_u: 0.4848 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 290/400
# 20/20 [==============================] - 175s 9s/step - loss: 118.0916 - mean_io_u: 0.4850 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 291/400
# 20/20 [==============================] - 173s 9s/step - loss: 117.9510 - mean_io_u: 0.4850 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 292/400
# 20/20 [==============================] - 172s 9s/step - loss: 112.1371 - mean_io_u: 0.4857 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 293/400
# 20/20 [==============================] - 172s 9s/step - loss: 122.4972 - mean_io_u: 0.4844 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 294/400
# 20/20 [==============================] - 171s 9s/step - loss: 121.5050 - mean_io_u: 0.4846 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 295/400
# 20/20 [==============================] - 173s 9s/step - loss: 117.7359 - mean_io_u: 0.4850 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 296/400
# 20/20 [==============================] - 172s 9s/step - loss: 115.3205 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 297/400
# 20/20 [==============================] - 172s 9s/step - loss: 114.8526 - mean_io_u: 0.4854 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 298/400
# 20/20 [==============================] - 174s 9s/step - loss: 113.2844 - mean_io_u: 0.4856 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 299/400
# 20/20 [==============================] - 173s 9s/step - loss: 122.5106 - mean_io_u: 0.4844 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 300/400
# 20/20 [==============================] - 174s 9s/step - loss: 112.1060 - mean_io_u: 0.4857 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 301/400
# 20/20 [==============================] - 172s 9s/step - loss: 121.9095 - mean_io_u: 0.4845 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 302/400
# 20/20 [==============================] - 173s 9s/step - loss: 123.1885 - mean_io_u: 0.4843 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 303/400
# 20/20 [==============================] - 171s 9s/step - loss: 114.9550 - mean_io_u: 0.4854 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 304/400
# 20/20 [==============================] - 172s 9s/step - loss: 120.5780 - mean_io_u: 0.4847 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 305/400
# 20/20 [==============================] - 172s 9s/step - loss: 110.0604 - mean_io_u: 0.4860 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 306/400
# 20/20 [==============================] - 171s 9s/step - loss: 115.2725 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 307/400
# 20/20 [==============================] - 172s 9s/step - loss: 118.1441 - mean_io_u: 0.4850 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 308/400
# 20/20 [==============================] - 173s 9s/step - loss: 110.9941 - mean_io_u: 0.4859 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 309/400
# 20/20 [==============================] - 172s 9s/step - loss: 118.0701 - mean_io_u: 0.4850 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 310/400
# 20/20 [==============================] - 173s 9s/step - loss: 112.4495 - mean_io_u: 0.4857 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 311/400
# 20/20 [==============================] - 174s 9s/step - loss: 119.5351 - mean_io_u: 0.4848 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 312/400
# 20/20 [==============================] - 174s 9s/step - loss: 114.6550 - mean_io_u: 0.4854 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 313/400
# 20/20 [==============================] - 172s 9s/step - loss: 116.8090 - mean_io_u: 0.4852 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 314/400
# 20/20 [==============================] - 172s 9s/step - loss: 117.7091 - mean_io_u: 0.4850 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 315/400
# 20/20 [==============================] - 173s 9s/step - loss: 113.4552 - mean_io_u: 0.4856 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 316/400
# 20/20 [==============================] - 173s 9s/step - loss: 124.1515 - mean_io_u: 0.4842 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 317/400
# 20/20 [==============================] - 174s 9s/step - loss: 115.3150 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 318/400
# 20/20 [==============================] - 175s 9s/step - loss: 118.8087 - mean_io_u: 0.4849 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 319/400
# 20/20 [==============================] - 174s 9s/step - loss: 115.1064 - mean_io_u: 0.4854 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 320/400
# 20/20 [==============================] - 173s 9s/step - loss: 124.6093 - mean_io_u: 0.4842 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 321/400
# 20/20 [==============================] - 174s 9s/step - loss: 114.6941 - mean_io_u: 0.4854 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 322/400
# 20/20 [==============================] - 172s 9s/step - loss: 114.0920 - mean_io_u: 0.4855 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 323/400
# 20/20 [==============================] - 173s 9s/step - loss: 112.8162 - mean_io_u: 0.4857 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 324/400
# 20/20 [==============================] - 172s 9s/step - loss: 119.8045 - mean_io_u: 0.4848 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 325/400
# 20/20 [==============================] - 175s 9s/step - loss: 121.5687 - mean_io_u: 0.4845 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 326/400
# 20/20 [==============================] - 172s 9s/step - loss: 122.1897 - mean_io_u: 0.4845 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 327/400
# 20/20 [==============================] - 176s 9s/step - loss: 114.3986 - mean_io_u: 0.4855 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 328/400
# 20/20 [==============================] - 173s 9s/step - loss: 122.8704 - mean_io_u: 0.4844 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 329/400
# 20/20 [==============================] - 174s 9s/step - loss: 118.4886 - mean_io_u: 0.4849 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 330/400
# 20/20 [==============================] - 172s 9s/step - loss: 115.0230 - mean_io_u: 0.4854 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 331/400
# 20/20 [==============================] - 173s 9s/step - loss: 111.5795 - mean_io_u: 0.4858 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 332/400
# 20/20 [==============================] - 173s 9s/step - loss: 114.4540 - mean_io_u: 0.4855 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 333/400
# 20/20 [==============================] - 172s 9s/step - loss: 112.0782 - mean_io_u: 0.4858 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 334/400
# 20/20 [==============================] - 173s 9s/step - loss: 111.6410 - mean_io_u: 0.4858 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 335/400
# 20/20 [==============================] - 174s 9s/step - loss: 107.3021 - mean_io_u: 0.4864 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 336/400
# 20/20 [==============================] - 173s 9s/step - loss: 113.8874 - mean_io_u: 0.4855 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 337/400
# 20/20 [==============================] - 174s 9s/step - loss: 116.9586 - mean_io_u: 0.4851 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 338/400
# 20/20 [==============================] - 173s 9s/step - loss: 111.9036 - mean_io_u: 0.4858 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 339/400
# 20/20 [==============================] - 170s 9s/step - loss: 118.5595 - mean_io_u: 0.4849 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 340/400
# 20/20 [==============================] - 172s 9s/step - loss: 117.3539 - mean_io_u: 0.4851 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 341/400
# 20/20 [==============================] - 173s 9s/step - loss: 119.4595 - mean_io_u: 0.4848 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 342/400
# 20/20 [==============================] - 172s 9s/step - loss: 118.4989 - mean_io_u: 0.4849 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 343/400
# 20/20 [==============================] - 173s 9s/step - loss: 119.6239 - mean_io_u: 0.4848 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 344/400
# 20/20 [==============================] - 174s 9s/step - loss: 116.2379 - mean_io_u: 0.4852 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 345/400
# 20/20 [==============================] - 172s 9s/step - loss: 118.2011 - mean_io_u: 0.4850 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 346/400
# 20/20 [==============================] - 174s 9s/step - loss: 116.9697 - mean_io_u: 0.4851 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 347/400
# 20/20 [==============================] - 172s 9s/step - loss: 118.1198 - mean_io_u: 0.4850 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 348/400
# 20/20 [==============================] - 172s 9s/step - loss: 109.1358 - mean_io_u: 0.4861 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 349/400
# 20/20 [==============================] - 172s 9s/step - loss: 117.4916 - mean_io_u: 0.4851 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 350/400
# 20/20 [==============================] - 173s 9s/step - loss: 118.1934 - mean_io_u: 0.4850 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 351/400
# 20/20 [==============================] - 172s 9s/step - loss: 113.6540 - mean_io_u: 0.4856 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 352/400
# 20/20 [==============================] - 173s 9s/step - loss: 115.0476 - mean_io_u: 0.4854 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 353/400
# 20/20 [==============================] - 172s 9s/step - loss: 112.4746 - mean_io_u: 0.4857 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 354/400
# 20/20 [==============================] - 175s 9s/step - loss: 115.5723 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 355/400
# 20/20 [==============================] - 173s 9s/step - loss: 116.5382 - mean_io_u: 0.4852 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 356/400
# 20/20 [==============================] - 169s 9s/step - loss: 116.8261 - mean_io_u: 0.4851 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 357/400
# 20/20 [==============================] - 174s 9s/step - loss: 122.0641 - mean_io_u: 0.4845 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 358/400
# 20/20 [==============================] - 174s 9s/step - loss: 114.3581 - mean_io_u: 0.4855 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 359/400
# 20/20 [==============================] - 173s 9s/step - loss: 121.0831 - mean_io_u: 0.4846 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 360/400
# 20/20 [==============================] - 173s 9s/step - loss: 113.1305 - mean_io_u: 0.4856 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 361/400
# 20/20 [==============================] - 173s 9s/step - loss: 116.6957 - mean_io_u: 0.4852 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 362/400
# 20/20 [==============================] - 174s 9s/step - loss: 127.1354 - mean_io_u: 0.4838 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 363/400
# 20/20 [==============================] - 172s 9s/step - loss: 114.1878 - mean_io_u: 0.4855 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 364/400
# 20/20 [==============================] - 173s 9s/step - loss: 122.8058 - mean_io_u: 0.4844 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 365/400
# 20/20 [==============================] - 175s 9s/step - loss: 120.7099 - mean_io_u: 0.4847 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 366/400
# 20/20 [==============================] - 173s 9s/step - loss: 123.4077 - mean_io_u: 0.4843 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 367/400
# 20/20 [==============================] - 174s 9s/step - loss: 115.3866 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 368/400
# 20/20 [==============================] - 172s 9s/step - loss: 128.1657 - mean_io_u: 0.4837 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 369/400
# 20/20 [==============================] - 173s 9s/step - loss: 115.1775 - mean_io_u: 0.4854 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 370/400
# 20/20 [==============================] - 173s 9s/step - loss: 117.0114 - mean_io_u: 0.4851 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 371/400
# 20/20 [==============================] - 170s 9s/step - loss: 119.3826 - mean_io_u: 0.4848 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 372/400
# 20/20 [==============================] - 173s 9s/step - loss: 113.9898 - mean_io_u: 0.4855 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 373/400
# 20/20 [==============================] - 171s 9s/step - loss: 120.7181 - mean_io_u: 0.4847 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 374/400
# 20/20 [==============================] - 173s 9s/step - loss: 119.2251 - mean_io_u: 0.4848 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 375/400
# 20/20 [==============================] - 173s 9s/step - loss: 115.2229 - mean_io_u: 0.4854 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 376/400
# 20/20 [==============================] - 171s 9s/step - loss: 115.4444 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 377/400
# 20/20 [==============================] - 172s 9s/step - loss: 124.9312 - mean_io_u: 0.4841 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 378/400
# 20/20 [==============================] - 174s 9s/step - loss: 115.0786 - mean_io_u: 0.4854 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 379/400
# 20/20 [==============================] - 173s 9s/step - loss: 123.1799 - mean_io_u: 0.4843 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 380/400
# 20/20 [==============================] - 172s 9s/step - loss: 120.9893 - mean_io_u: 0.4846 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 381/400
# 20/20 [==============================] - 172s 9s/step - loss: 113.0108 - mean_io_u: 0.4856 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 382/400
# 20/20 [==============================] - 173s 9s/step - loss: 117.6483 - mean_io_u: 0.4850 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 383/400
# 20/20 [==============================] - 174s 9s/step - loss: 122.8374 - mean_io_u: 0.4844 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 384/400
# 20/20 [==============================] - 173s 9s/step - loss: 116.3223 - mean_io_u: 0.4852 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 385/400
# 20/20 [==============================] - 173s 9s/step - loss: 117.9310 - mean_io_u: 0.4850 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 386/400
# 20/20 [==============================] - 174s 9s/step - loss: 113.6548 - mean_io_u: 0.4856 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 387/400
# 20/20 [==============================] - 174s 9s/step - loss: 114.3350 - mean_io_u: 0.4855 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 388/400
# 20/20 [==============================] - 172s 9s/step - loss: 117.7355 - mean_io_u: 0.4850 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 389/400
# 20/20 [==============================] - 173s 9s/step - loss: 114.6766 - mean_io_u: 0.4854 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 390/400
# 20/20 [==============================] - 173s 9s/step - loss: 118.6473 - mean_io_u: 0.4849 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 391/400
# 20/20 [==============================] - 170s 9s/step - loss: 111.8011 - mean_io_u: 0.4858 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 392/400
# 20/20 [==============================] - 174s 9s/step - loss: 116.9312 - mean_io_u: 0.4851 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 393/400
# 20/20 [==============================] - 179s 9s/step - loss: 112.5183 - mean_io_u: 0.4857 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 394/400
# 20/20 [==============================] - 175s 9s/step - loss: 116.2758 - mean_io_u: 0.4852 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 395/400
# 20/20 [==============================] - 177s 9s/step - loss: 115.3709 - mean_io_u: 0.4853 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 396/400
# 20/20 [==============================] - 173s 9s/step - loss: 110.4311 - mean_io_u: 0.4860 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 397/400
# 20/20 [==============================] - 173s 9s/step - loss: 119.6240 - mean_io_u: 0.4848 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 398/400
# 20/20 [==============================] - 174s 9s/step - loss: 114.6929 - mean_io_u: 0.4854 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 399/400
# 20/20 [==============================] - 174s 9s/step - loss: 120.9170 - mean_io_u: 0.4846 - val_loss: 111.9622 - val_mean_io_u: 0.2429
# Epoch 400/400
# 20/20 [==============================] - 172s 9s/step - loss: 118.1349 - mean_io_u: 0.4850 - val_loss: 111.9622 - val_mean_io_u: 0.2429

# %%
# Save the entire model(shoule be with weights) and the weights
kiunet_model.save('kiUnet_model')
kiunet_model.save_weights('kiUnet_saved_weight')
# Out:
# INFO:tensorflow:Assets written to: kiUnet_model/assets
